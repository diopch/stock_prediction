# %%
from stock_prediction.arima import arima_multi_day
from stock_prediction.workflow import data_collection, call_arima
from datetime import datetime

# %%
start_date = '2021-05-01'

# %%
dict_hard_data, dict_prep_data, df_es50 = data_collection(start_date)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ...

# %%
dict_arima = call_arima(start_date, dict_prep_data,alpha=0.05)
# Out:
# /Users/arnaudraybaud/.pyenv/versions/3.8.6/envs/stock_prediction/lib/python3.8/site-packages/statsmodels/tsa/arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# ...

# %%
dict_arima['asml']
# Out:
#              yesterday  prediction    conf_low   conf_high        true  \
# Date
# 2021-04-13  111.633852  110.265347  107.373581  113.157112  111.910592
# 2021-04-14  111.910592  112.527099  109.599662  115.454536  112.889829
# 2021-04-15  112.889829  113.575473  110.646737  116.504210  112.804688
# 2021-04-16  112.804688  114.691044  111.776826  117.605261  114.188403
# 2021-04-19  114.188403  111.492722  108.575048  114.410397  111.165512
# 2021-04-20  111.165512  108.798165  105.878985  111.717344  108.994146
# 2021-04-21  108.994146  108.547670  105.632010  111.463330  113.443323
# 2021-04-22  113.443323  112.947396  109.692668  116.202124  115.742426
# 2021-04-23  115.742426  118.257504  114.903734  121.611274  117.956361
# 2021-04-26  117.956361  119.677847  116.402747  122.952946  118.573704
# 2021-04-27  118.573704  118.951841  115.835692  122.067990  117.658329
# 2021-04-28  117.658329  117.755777  114.618102  120.893452  117.040973
# ...

# %% [markdown]
# - 1 action 1 période sélectionnée
# - grid search
# - parametres
# - 1 autre action
# - grid search
# - regarde si les param changent
# - si pas de changement notable : tu peux généraliser les params
# - reprendre les actions testées : fais varier le alpha
# - trouve le alpha bon
# - crée ta boucle sur company_lsit
# - pour chaque action tu save un modèle
